# %% [markdown]
# # Анализ развлекательного приложения Procrastinate Pro+

# %% [markdown]
# ## Описание проекта
#
# Вы — маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Ваша задача — разобраться в причинах и помочь компании выйти в плюс.
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# Вам предстоит изучить:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# ### Описание данных
#
# В вашем распоряжении три датасета:
# - visits_info_short.csv — хранит лог сервера с информацией о посещениях сайта
# - orders_info_short.csv — информацию о заказах
# - costs_info_short.csv — информацию о расходах на рекламу.
#
# Структура visits_info_short.csv:
# - User Id — уникальный идентификатор пользователя,
# - Region — страна пользователя,
# - Device — тип устройства пользователя,
# - Channel — идентификатор источника перехода,
# - Session Start — дата и время начала сессии,
# - Session End — дата и время окончания сессии.
#
# Структура orders_info_short.csv:
# - User Id — уникальный идентификатор пользователя,
# - Event Dt — дата и время покупки,
# - Revenue — сумма заказа.
#
# Структура costs_info_short.csv:
# - dt — дата проведения рекламной кампании,
# - Channel — идентификатор рекламного источника,
# - costs — расходы на эту кампанию.
#
# ### Инструкция по выполнению проекта
#
# #### Шаг 1. Загрузите данные и подготовьте их к анализу
# - загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные. Пути к файлам:
#     - /datasets/visits_info_short.csv. Скачать датасет;
#     - /datasets/orders_info_short.csv. Скачать датасет;
#     - /datasets/costs_info_short.csv. Скачать датасет.
# - изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.
#
# #### Шаг 2. Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
# - разрешается использовать функции, с которыми вы познакомились в теоретических уроках. Это функции для вычисления значений метрик, а также функции для построения графиков:
#     - get_profiles() — для создания профилей пользователей,
#     - get_retention() — для подсчёта Retention Rate,
#     - get_conversion() — для подсчёта конверсии,
#     - get_ltv() — для подсчёта LTV,
#     - filter_data() — для сглаживания данных,
#     - plot_retention() — для построения графика Retention Rate,
#     - plot_conversion() — для построения графика конверсии,
#     - plot_ltv_roi — для визуализации LTV и ROI.
#
# #### Шаг 3. Исследовательский анализ данных
# - составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. - постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
# - после каждого пункта сформулируйте выводы.
#
# #### Шаг 4. Маркетинг
# - посчитайте общую сумму расходов на маркетинг.
# - выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - постройте график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
# - узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
# - напишите промежуточные выводы.
#
# #### Шаг 5. Оцените окупаемость рекламы
# - используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
# - проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - ответьте на такие вопросы:
#     - окупается ли реклама, направленная на привлечение пользователей в целом?
#     - какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - чем могут быть вызваны проблемы окупаемости?
#     - напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.
#
# #### Шаг 6. Напишите выводы
# - выделите причины неэффективности привлечения пользователей.
# - сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# ## Изучение данных

# %% [markdown]
# ### Загрузим данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %%
# импортируем все необходимые библиотеки для исследования
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# прочитаем все датафреймы и сохраним их в переменные
visits = pd.read_csv('/datasets/visits_info_short.csv', parse_dates=['Session Start', 'Session End'])
orders = pd.read_csv('/datasets/orders_info_short.csv', parse_dates=['Event Dt'])
costs = pd.read_csv('/datasets/costs_info_short.csv', parse_dates=['dt'])

# %% [markdown]
# #### Изучим датафрейм 'visits'

# %%
# создадим функцию для быстрого просмотра всей нужной информации датафрейма 'visits'
def display_and_info(visits):
    display(visits.head())
    display(visits.info())
    display(visits.describe().T)

# %%
# посмотрим на общую информацию
display_and_info(visits)
# Out:
#         User Id         Region   Device  Channel       Session Start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           Session End
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# 4 2019-05-01 03:57:40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
# ...

# %% [markdown]
# В датафрейме 'visits' необходимо привести наименования всех столбцов к "змеиному" стилю. Также необходимо было привести столбцы с началом и концом сессии к нужному типу данных - datetime. Сделали это при чтении датафрейма. В данном датафрейме пропусков нет

# %% [markdown]
# #### Изучим датафрейм 'orders'

# %%
# создадим функцию для быстрого просмотра всей нужной информации датафрейма 'orders'
def display_and_info(orders):
    display(orders.head())
    display(orders.info())
    display(orders.describe().T)

# %%
# посмотрим на общую информацию
display_and_info(orders)
# Out:
#         User Id            Event Dt  Revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  datetime64[ns]
#  2   Revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# None
#            count          mean           std        min           25%  \
# User Id  40212.0  4.990295e+11  2.860937e+11  599326.00  2.511324e+11
# Revenue  40212.0  5.370608e+00  3.454208e+00       4.99  4.990000e+00
#
#                   50%           75%           max
# ...

# %% [markdown]
# В датафрейме 'orders' необходимо привести наименования всех столбцов к "змеиному" стилю. Тип данных у столбца 'Event Dt' изменил при чтении датафрейма. В данном датафрейме пропусков нет

# %% [markdown]
# #### Изучим датафрейм 'costs'

# %%
# создадим функцию для быстрого просмотра всей нужной информации датафрейма 'costs'
def display_and_info(costs):
    display(costs.head())
    display(costs.info())
    display(costs.describe().T)

# %%
# посмотрим на общую информацию
display_and_info(costs)
# Out:
#           dt   Channel  costs
# 0 2019-05-01  FaceBoom  113.3
# 1 2019-05-02  FaceBoom   78.1
# 2 2019-05-03  FaceBoom   85.8
# 3 2019-05-04  FaceBoom  136.4
# 4 2019-05-05  FaceBoom  122.1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   datetime64[ns]
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB
# None
#         count       mean         std  min    25%     50%   75%    max
# costs  1800.0  58.609611  107.740223  0.8  6.495  12.285  33.6  630.0

# %% [markdown]
# В датафрейме 'costs' необходимо привести наименования столбца с каналами к "змеиному" стилю. Тип данных у столбца 'dt' изменил при чтении датафрейма. В данном датафрейме пропусков нет

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Проверим наши датафреймы на наличие явных и неявных дубликатов

# %%
# проверяем датафрейм 'visits' на наличие явных дубликатов
visits.duplicated().sum()
# Out:
# 0

# %%
# проверяем датафрейм 'visits' на наличие неявных дубликатов
# для этого сгруппируем по столбцам ID пользователя и началу сессии
# понятное дело, что один и тот же пользователь может много раз начать сессию, но не в одну и ту же секунду одной и той же даты
visits.groupby('User Id')['Session Start'].value_counts().sort_values()
# Out:
# User Id       Session Start
# 599326        2019-05-07 20:58:57    1
# 666433868763  2019-10-05 00:09:54    1
# 666429382181  2019-10-29 18:46:19    1
#               2019-10-26 09:33:37    1
# 666414214624  2019-09-25 11:24:36    1
#                                     ..
# 332720746034  2019-09-21 04:44:04    1
#               2019-09-20 20:11:08    1
# 332710395955  2019-05-25 06:39:45    1
# 332703136860  2019-06-28 13:20:01    1
# 999999563947  2019-10-20 04:10:34    1
# Name: Session Start, Length: 309901, dtype: int64

# %%
# проверяем датафрейм 'orders' на наличие явных дубликатов
orders.duplicated().sum()
# Out:
# 0

# %%
# проверяем датафрейм 'orders' на наличие неявных дубликатов
# для этого сгруппируем по столбцам ID пользователя и дате и времени покупки
orders.groupby('User Id')['Event Dt'].value_counts().sort_values()
# Out:
# User Id       Event Dt
# 599326        2019-05-07 20:59:09    1
# 660764823805  2019-07-17 09:03:36    1
#               2019-08-05 21:01:38    1
#               2019-08-10 23:57:13    1
# 660787742648  2019-09-24 15:22:07    1
#                                     ..
# 338343388023  2019-05-17 12:39:43    1
#               2019-05-19 17:44:07    1
#               2019-05-26 15:01:30    1
# 338276441244  2019-07-12 14:08:50    1
# 999895427370  2019-09-19 23:33:23    1
# Name: Event Dt, Length: 40212, dtype: int64

# %%
# проверяем датафрейм 'costs' на наличие явных дубликатов
costs.duplicated().sum()
# Out:
# 0

# %%
# проверяем датафрейм 'costs' на наличие неявных дубликатов
# для этого сгруппируем по столбцам даты проведения рекламной компании и рекламному источнику
costs.groupby('dt')['Channel'].value_counts().sort_values()
# Out:
# dt          Channel
# 2019-05-01  AdNonSense            1
# 2019-08-29  TipTop                1
#             RocketSuperAds        1
#             OppleCreativeMedia    1
#             MediaTornado          1
#                                  ..
# 2019-06-29  OppleCreativeMedia    1
#             MediaTornado          1
#             LeapBob               1
# 2019-06-26  LeapBob               1
# 2019-10-27  lambdaMediaAds        1
# Name: Channel, Length: 1800, dtype: int64

# %% [markdown]
# Во всех датафреймах явных и неявных дубликатов нет

# %% [markdown]
# #### Приведём столбцы датафреймов к единому "змеиному" стилю

# %%
# приведем название столбцов к единому стилю в датафрейме 'visits'
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]

# %%
# проверим наименования столбцов в датафрейме 'visits'
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
# приведем название столбцов к единому стилю в датафрейме 'orders'
orders = orders.rename(columns = {'User Id': 'user_id', 'Event Dt': 'event_dt', 'Revenue': 'revenue'})

# %%
# проверим наименования столбцов в датафрейме 'orders'
orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
# приведем название столбцов к единому стилю в датафрейме 'costs'
costs = costs.rename(columns = {'Channel': 'channel'})

# %%
# проверим наименования столбцов в датафрейме 'costs'
costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# Вывод:
# - провели предобработку данных
# - дубликатов нет
# - во всех датафреймах наименования столбцов изменены на "змеиный" стиль.

# %% [markdown]
# ## Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Воспользуемся готовыми функциями, описанными в теоретической части, но чуть изменим их под наши задачи.

# %% [markdown]
# ### Функция для создания профилей пользователей

# %%
# get_profiles - функция для получения пользовательских профилей

def get_profiles(sessions, orders, ad_costs):
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    # приводим тип dt к datetime
    new_users['dt'] = pd.to_datetime(new_users['dt'])
    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')
    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    # приводим dt в profiles к типу datetime
    profiles['dt'] = pd.to_datetime(profiles['dt'])
    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )
    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для подсчёта Retention Rate

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания данных

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для построения графика Retention Rate

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для построения графика конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Составим профиль пользователей. Определим минимальную и максимальную даты привлечения пользователей.

# %%
# получим пользовательские профили
profiles = get_profiles(visits, orders, costs)

# %%
# узнаем минимальную и максимальную даты привлечения
print(f'''Минимальная дата привлечения пользователей: {profiles['dt'].min()}
Максимальная дата привлечения пользователей: {profiles['dt'].max()}''')
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01 00:00:00
# Максимальная дата привлечения пользователей: 2019-10-27 00:00:00

# %% [markdown]
# Также назначим момент и горизонт анализа из пункта 5. Горизонт анализа у нас 2 недели, т.е. 14 дней, а момент анализа мы возьмём не 1 ноября 2019 года, а максимальную дату привлечения пользователей.

# %%
# назначим момент и горизонт анализа
observation_date = profiles['dt'].max()
horizon_days = 14

# %% [markdown]
# ### Выясним, из каких стран пользователи приходят в приложение и в какой стране больше всего платящих клиентов.

# %%
# посмотрим на список стран из столбца регион
profiles['region'].unique()
# Out:
# array(['United States', 'France', 'Germany', 'UK'], dtype=object)

# %%
# создадим новый датафрейм для подсчёта пользователей по странам
region_payer = pd.DataFrame()

# %%
# найдём общее количество пользователей по странам
# под общим я подразумеваю платящих и неплатящих
region_payer['users_count'] = profiles.groupby('region')['user_id'].count()
region_payer['users_count'].sort_values(ascending=False)
# Out:
# region
# United States    100002
# UK                17575
# France            17450
# Germany           14981
# Name: users_count, dtype: int64

# %%
# найдём количество платящих пользователей по странам
region_payer['users_count_payer'] = profiles.query('payer == True').groupby('region')['user_id'].count()
region_payer['users_count_payer'].sort_values(ascending=False)
# Out:
# region
# United States    6902
# UK                700
# France            663
# Germany           616
# Name: users_count_payer, dtype: int64

# %%
# найдём долю платящих пользователей по странам в %
region_payer['share'] = (region_payer['users_count_payer'] / region_payer['users_count']) * 100
region_payer['share'].sort_values(ascending=False)
# Out:
# region
# United States    6.901862
# Germany          4.111875
# UK               3.982930
# France           3.799427
# Name: share, dtype: float64

# %%
# выведем весь список отсортировав его по доле платящих клиентов в порядке убывания по странам
region_payer.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_0fc8b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_count</th>        <th class="col_heading level0 col1" >users_count_payer</th>        <th class="col_heading level0 col2" >share</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0fc8b_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_0fc8b_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_0fc8b_row0_col1" class="data row0 col1" >6902</td>
#                         <td id="T_0fc8b_row0_col2" class="data row0 col2" >6.90%</td>
#             </tr>
#             <tr>
# ...

# %%
# построим столбчатый график для наглядности количества пользователей по странам
region_payer.sort_values(by='users_count', ascending=False).plot(kind='bar', figsize=(12, 8), grid=True)
plt.title('Количество платящих и общих пользователей по странам')
plt.xlabel('Страна')
plt.ylabel('Количество пользователей')
plt.show()

# %% [markdown]
# Больше всего пользователей из США как платящих, так и не платящих. Далее идут почти вровень Великобритания и Франция как по общему количеству пользователей, так и по платящим. Меньше всего пользователей из Германии, но процент платящих там выше чем из Великобритании и Франции.

# %% [markdown]
# ### Узнаем какими устройствами больше всего пользуются пользователи приложения и какое устройство самое популярное средь платящих клиентов.

# %%
# посмотрим на список устройств
profiles['device'].unique()
# Out:
# array(['Mac', 'iPhone', 'PC', 'Android'], dtype=object)

# %%
# создадим новый датафрейм для подсчёта пользователей по устройствам
device_payer = pd.DataFrame()
# найдем общее количество пользователей по утсройствам
device_payer['users_count'] = profiles.groupby('device')['user_id'].count()
device_payer['users_count'].sort_values(ascending=False)
# Out:
# device
# iPhone     54479
# Android    35032
# PC         30455
# Mac        30042
# Name: users_count, dtype: int64

# %%
# найдём количество платящих пользователей по устройствам
device_payer['users_count_payer'] = profiles.query('payer == True').groupby('device')['user_id'].count()
device_payer['share'] = (device_payer['users_count_payer'] / device_payer['users_count']) * 100
device_payer.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_ebdf4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_count</th>        <th class="col_heading level0 col1" >users_count_payer</th>        <th class="col_heading level0 col2" >share</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ebdf4_level0_row0" class="row_heading level0 row0" >Mac</th>
#                         <td id="T_ebdf4_row0_col0" class="data row0 col0" >30042</td>
#                         <td id="T_ebdf4_row0_col1" class="data row0 col1" >1912</td>
#                         <td id="T_ebdf4_row0_col2" class="data row0 col2" >6.36%</td>
#             </tr>
#             <tr>
# ...

# %%
# построим столбчатый график для наглядности количества пользователей по устройствам
device_payer.sort_values(by='users_count', ascending=False).plot(kind='bar', figsize=(12, 8), grid=True)
plt.title('Количество платящих и общих пользователей по устройствам')
plt.xlabel('Устройство')
plt.ylabel('Количество пользователей')
plt.show()

# %% [markdown]
# Больше всего пользователей используют iPhone, также доля платящих у них самая высокая после устройств Mac. Кстати говоря пользователей на Mac меньше всего, но больше всего средь них доля платящих клиентов.

# %% [markdown]
# ### Изучим рекламные источники привлечения и определим из какого канала больше всего пришло платящих клиентов.

# %%
# посмотрим на список рекламных источников
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %%
# создадим новый датафрейм для подсчёта привлечённых пользователей по рекламным источникам
channel_payer = pd.DataFrame()
# найдем общее количество привлечённых пользователей по рекламным источникам
channel_payer['users_count'] = profiles.groupby('channel')['user_id'].count()
channel_payer['users_count'].sort_values(ascending=False)
# Out:
# channel
# organic               56439
# FaceBoom              29144
# TipTop                19561
# OppleCreativeMedia     8605
# LeapBob                8553
# WahooNetBanner         8553
# RocketSuperAds         4448
# MediaTornado           4364
# YRabbit                4312
# AdNonSense             3880
# lambdaMediaAds         2149
# Name: users_count, dtype: int64

# %%
# найдём количество платящих пользователей по устройствам
channel_payer['users_count_payer'] = profiles.query('payer == True').groupby('channel')['user_id'].count()
channel_payer['share'] = (channel_payer['users_count_payer'] / channel_payer['users_count']) * 100
channel_payer.sort_values(by='share', ascending=False).style.format({'share': '{:.2f}%'})
# Out:
# <style  type="text/css" >
# </style><table id="T_ae0d5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users_count</th>        <th class="col_heading level0 col1" >users_count_payer</th>        <th class="col_heading level0 col2" >share</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae0d5_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#                         <td id="T_ae0d5_row0_col0" class="data row0 col0" >29144</td>
#                         <td id="T_ae0d5_row0_col1" class="data row0 col1" >3557</td>
#                         <td id="T_ae0d5_row0_col2" class="data row0 col2" >12.20%</td>
#             </tr>
#             <tr>
# ...

# %%
# построим столбчатый график для наглядности количества привлечённых пользователей по рекламным источникам
channel_payer.sort_values(by='users_count', ascending=False).plot(kind='bar', figsize=(12, 8), grid=True)
plt.title('Количество платящих и общих привлечённых пользователей по рекламным источникам')
plt.xlabel('Рекламный источник')
plt.ylabel('Количество пользователей')
plt.show()

# %% [markdown]
# Если не брать в расчёт "органически" привлечённых пользователей, то больше всего платящих пользователей пришло из 4х рекламных источников: FaceBoom, AdNonSense, lambdaMediaAds и TipTop. При этом если опять же не брать "органически" привлечённых пользователей можно заметить, что на рекламные источники - FaceBoom и TipTop приходится больше половины всех привлечённых пользователей.

# %% [markdown]
# ## Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# ### Посчитаем общую сумму расходов на маркетинг

# %%
# посмотрим сколько всего было потрачно на рекламу во всех рекламных источниках
costs['costs'].sum().round()
# Out:
# 105497.0

# %% [markdown]
# ### Посмотрим на распределение трат по рекламным источникам

# %%
# создадим датафрейм для подсчтёта трат по рекламным источникам
costs_channel = costs.groupby('channel')['costs'].sum()
costs_channel.sort_values(ascending=False)
# Out:
# channel
# TipTop                54751.30
# FaceBoom              32445.60
# WahooNetBanner         5151.00
# AdNonSense             3911.25
# OppleCreativeMedia     2151.25
# RocketSuperAds         1833.00
# LeapBob                1797.60
# lambdaMediaAds         1557.60
# MediaTornado            954.48
# YRabbit                 944.22
# Name: costs, dtype: float64

# %% [markdown]
# Больше всего потрачено на рекламные источники - TipTop и FaceBoom, больше 82% от всего бюджета. Теперь ясно почему эти источники в топе по привлечению пользователей.

# %% [markdown]
# ### Построим график с визуализацией динамики изменения расходов во времени

# %%
# создадим переменные из датафрейма 'costs' по расходам на рекламные компании по неделям и по месяцам
costs['week'] = costs['dt'].dt.isocalendar().week
costs['month'] = costs['dt'].dt.month

# %% [markdown]
# Построим график с визуализацией динамики изменения расходов по неделям

# %%
# создаём сводную таблицу по каналам и неделям
report_week = costs.pivot_table(index='channel', columns='week', values='costs', aggfunc='sum')

# %%
# строим график динамики расходов по неделям
report_week.T.plot(grid=True, figsize=(20, 12))
plt.title('Динамика расходов по неделям')
plt.xlabel('Неделя')
plt.ylabel('Расходы')
plt.show()

# %% [markdown]
# В целом основные траты можно выделить только в 2 рекламные компании - TipTop и FaceBoom. На протяжении всех недель (с 18 по 43 вкл) по графику видно, что траты были по большей части в одно и тоже время с разницей только по суммам расходов.

# %% [markdown]
# Построим график с визуализацией динамики изменения расходов по месяцам

# %%
# создаём сводную таблицу по каналам и месяцам
report_month = costs.pivot_table(index='channel', columns='month', values='costs', aggfunc='sum')
# строим график динамики расходов по месяцам
report_month.T.plot(grid=True, figsize=(20, 12))
plt.title('Динамика расходов по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Расходы')
plt.show()

# %% [markdown]
# Также как и по неделям естественно на графике по месяцам видно, что основные траты на 2 рекламные компании - TipTop и FaceBoom. Причём на этом графике видно, что расходы FaceBoom примерно одинаковые на протяжении всего времени, а расходы на TipTop только возрастали и достигли пика в сентябре 2019 года. В октябре скорее всего были бы такие же и как в сентябре, но не весь октябрь вошёл в исследование, только по 27 октябяр включительно.

# %% [markdown]
# ### Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
# посмотрим в целом для начала числовое описание данных столбца 'acquisition_cost'
profiles['acquisition_cost'].describe()
# Out:
# count    150008.000000
# mean          0.703278
# std           0.954097
# min           0.000000
# 25%           0.000000
# 50%           0.247500
# 75%           1.108943
# max           3.715385
# Name: acquisition_cost, dtype: float64

# %%
# используем профили пользователей и сгруппируем по каналам
profiles.groupby('channel').agg({'acquisition_cost': 'mean'}).sort_values('acquisition_cost', ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %% [markdown]
# Самое дорогое привлечение пользователей вышло у рекламного источника - TipTop. Почти в 3 раза больше чем у идущего следующим - FaceBoom.

# %% [markdown]
# ## Оценим окупаемость рекламы

# %% [markdown]
# Перед построением всех графиков уберём из расчётов "органических" пользователей, т.к. затраты на них равны 0.

# %%
# убираем "органических" пользователей
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# ### Проанализируем окупаемость рекламы с помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Вывод:
# - LTV на периоде горизонта растёт
# - динамика LTV стабильно колеблется в районе 0.9
# - CAC растёт на протяжении всего исследования как и должно быть
# - ROI не окупается
# - динамика ROI перестаёт окупаться вообще ещё в середине июня

# %% [markdown]
# ### Проверим конверсию и удержание пользователей и динамику их изменений.

# %% [markdown]
# Проверим конверсию пользователей и динамику её изменения по трём критериям: устройствам, регионам и каналам привлечения. Также по этим критериям проверим удержание пользователей.

# %% [markdown]
# #### Проверяем конверсию и удержание пользователей по устройствам

# %%
# смотрим конверсию с разбивкой по устройствам
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия пользователей лучше всего у обладателей Mac и iPhone. Немного хуже идёт Android. Значительно хуже - PC. Динамика конверсии хуже всех у PC. У Mac и iPhone наблюдается примерно одинаковая динамика конверсии.

# %%
# смотрим удержание с разбивкой по устройствам
dimensions = ['device']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей немного лучше чем у неплатящих к концу 14 дня. (10-15% и около 0% соответственно)

# %% [markdown]
# #### Проверяем конверсию и удержание пользователей по странам

# %%
# смотрим конверсию с разбивкой по странам
dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия динамика конверсии у пользователей из США значительно лучше остальных стран.

# %%
# смотрим удержание с разбивкой по странам
dimensions = ['region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержания платящих пользователей из США хуже всех и ссотавляет к концу 14 дня ниже 10%. Лучше всего Франции и Великобритании - около 18%.

# %% [markdown]
# #### Проверяем конверсию и удержание пользователей по рекламным каналам

# %%
# смотрим конверсию с разбивкой по рекламным каналам
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Самая высокая конверсия по каналу - FaceBoom. Далее идут AdNonSense, lambdaMediaAds и TipTop.

# %%
# смотрим удержание с разбивкой по рекламным каналам
dimensions = ['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Хуже всего удерживаются платящие пользователи из рекламных каналов - FaceBoom и AdNonSense.

# %% [markdown]
# ### Проанализируем окупаемость рекламы и динамику их изменений

# %% [markdown]
# #### Проанализируем окупаемость рекламы с разбивкой по устройствам.

# %%
# введём категорию отбора с разбивкой по устройствам
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Вывод:
# - LTV на периоде горизонта растёт по всем устройствам примерно одинаково. Немного хуже остальных устройства - PC
# - динамика LTV по устройствам имеет примерно одни и те же очертания. Единственное что бросается в глаза, это динамика LTV примерно в 20х числах июля растёт по всем устройствам, кроме PC. У PC наблюдается резкое ухудшение динамики. То же самое можно наблюдать и в начале октября.
# - СAC растёт в целом на протяжении всего периода. Лидеры тут - Mac и iPhone. Хуже всех опять PC
# - в целом окупается только PC
# - динамика ROI перестаёт окупаться ещё в середине июня почти у всех, кроме PC. У Android наблюдаются ещё небольшие пики окупаемости. Хуже всего у Mac и iPhone

# %% [markdown]
# #### Проанализируйте окупаемость рекламы с разбивкой по странам.

# %%
# введём категорию отбора с разбивкой по странам
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Хочу обратить внимание на сходство стоимости привлечения `US` и `Tip Top` это неспроста)

# %% [markdown]
# Вывод:
# - LTV на периоде горизонта растёт у всех. Лучше всего у США
# - динамика LTV также лучше всего у США
# - CAC в конце мая проседает примерно с 0.6 до 0.4 у всех кроме США. У США наблюдается в целом стоимость привлечения выше чем у других стран. В середине мая идёт быстрый рост с 0.8 до 1.2 уже к началу июня. Далее от месяца к месяцу он также немного растёт и достигает почти 1.8. Это больше чем в 4 раза чем у других стран к 27 октября.
# - ROI окупается у всех кроме США. В Великобритании уже с 4 дня начинает окупаться и расти дальше, у Франции и Германии примерно с 5 дня. У США не окупается вообще
# - динамика ROI окупается у всех кроме США. Последний раз у США окупалась она в середине июня. Лучше всех здесь Великобритания. Особенно можно заметить резкие пики в середине июля и августа.

# %% [markdown]
# #### Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.

# %%
# введём категорию отбора с разбивкой по рекламным каналам
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Вывод:
# - LTV на периоде горизонта растёт у всех. Лучше всего у lambdaMediaAds и TipTop
# - динамика LTV примерна одинакова у всех, кроме lambdaMediaAds и TipTop. У lambdaMediaAds можно заметить резкие пики динамики на 14 день в середине июня да и в целом динамика lambdaMediaAds лучше других в несколько раз. Также можно отметить и TipTop, до lambdaMediaAds конечно далеко, но в среднем колеблется между 1 и 2 в отличии от других которые колеблятся в районе 0 и 1.
# - CAC стабилен у всех кроме TipTop. В середине мая начинается рост и идёт лесенкой от месяца к месяцу.
# - ROI окупается у всех кроме трёх рекламных каналов - TipTop, FaceBoom и AdNonSense
# - динамика ROI окупается у всех кроме тех же трёх каналов - TipTop, FaceBoom и AdNonSense.  Хотя у AdNonSense можно увидеть, что порой уровень выше чем уровень окупаемости. У TipTop и FaceBoom нет окупаемости вообще на протяжении всего периода. ЛУчше всех здесь YRabbit. У него летом много резких пиков и в начале сентября.

# %% [markdown]
# ### Ответим на вопросы связанные с окупаемостью рекламы

# %% [markdown]
# #### Окупается ли реклама, направленная на привлечение пользователей в целом?

# %% [markdown]
# В целом реклама не окупается

# %% [markdown]
# #### Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?

# %% [markdown]
# По устройствам особо всё ровно. Значит остаётся посмотреть по странам и каналам. Посмотрим для начала сколько стоит привлечение одного пользователя по странам.

# %%
# используем профили пользователей и сгруппируем по странам
profiles.groupby('region').agg({'acquisition_cost': 'mean'}).sort_values('acquisition_cost', ascending=False)
# Out:
#                acquisition_cost
# region
# United States          1.470646
# Germany                0.464339
# France                 0.459032
# UK                     0.454411

# %% [markdown]
# Привлечение пользователей из США в среднем стоит больше чем в 3 раза по сравнению с другими странами которые идут в одной ценовой категории. Посмотрим на графики без пользователей из США

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('region != "United States"'), orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Общая окупаемость рекламы достигает уже на 5 день и продолжает расти. Конечно же нельзя просто взять и исключить такой большой рынок как США, ведь там основная часть пользователей (2/3 всех пользователей) и самая большая доля платящих пользователей (почти 78% всех платящих пользователей).

# %%
# посмотрим на количество пользователей привлечённых без "органики"
profiles.groupby('region')['user_id'].count().sort_values(ascending=False)
# Out:
# region
# United States    61829
# UK               11154
# France           11058
# Germany           9528
# Name: user_id, dtype: int64

# %% [markdown]
# Теперь посмотрим на рекламные каналы. Как нам ранее стало известно, самое дорогое привлечение пользователей из рекламного канала - TipTop. Посмотрим на графики без пользователей привлечённых из данного канала

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "TipTop"'), orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Окупаемость рекламы без самого дорого канала уже к 10 дню. Посмотрим на количество привлечённых пользователей в разбивке по каналам, а также узнаем какое количество пользователей привлечено из  TipTop

# %%
# посмотрим на количество привлечённых пользователей из разных каналов
profiles.groupby('channel')['region'].count().sort_values(ascending=False)
# Out:
# channel
# FaceBoom              29144
# TipTop                19561
# OppleCreativeMedia     8605
# LeapBob                8553
# WahooNetBanner         8553
# RocketSuperAds         4448
# MediaTornado           4364
# YRabbit                4312
# AdNonSense             3880
# lambdaMediaAds         2149
# Name: region, dtype: int64

# %%
# постотрим на количество привлечённых пользователей из США по каналам привлечения
profiles.query('region == "United States"').groupby('channel')['region'].count().sort_values(ascending=False)
# Out:
# channel
# FaceBoom          29144
# TipTop            19561
# RocketSuperAds     4448
# MediaTornado       4364
# YRabbit            4312
# Name: region, dtype: int64

# %% [markdown]
# Получается 21% всех пользователей пришло из рекламного канала - TipTop, который работает только на пользователей из США.

# %% [markdown]
# #### Чем могут быть вызваны проблемы окупаемости?

# %% [markdown]
# Проблемы с окупаемостью связаны в первую очередь с неправильным распределением средств на рекламу. Стоит отказаться от дорогой рекламы от TipTop и присмотреться к таким рекламным источникам как - lambdaMediaAds. У неё лучший LTV, лучшая динамика LTV, окупаемость хорошая, средь лидеров и CAC чуть выше среднего. Да, конечно у неё худшие показатели по привлечённости средь других рекламных истчоников, но необходимо всегда выбирать между количеством и качеством. Если цель максимальное привлечение пользователей, то данный канал отлично в этом подходит, если же цель всё таки на рекламу которая будет хотя бы выходить в 0, т.е. окупаться, то стоит отказаться от данного рекламного канала привлечения.

# %% [markdown]
# ## ОБЩИЙ ВЫВОД:
#
# У нас было 3 датафрейма, содержащие информацию о посещении сайта, покупках и расходах на рекламу.
#
# 1. Изучение данных
#
# - Провели изучение датафреймов
# - Изменили типы данных где это требовалось
# - Изменили наименования столбцов
#
# 2. Задали функции для расчёта и анализа LTV, ROI, удержания и конверсии
#
# 3. Исследовательский анализ данных
# - Составили профили пользователей
# - Узнали минимальную и максимальную дату привлечения пользователей
# - Всего 4 страны в нашем ислледовании: США, Великобритания, Германия и Франция. Также узнали, что из США больше всего пользователей в целом и большее количество платящих пользователей
# - Всего 4 устройства используются пользователями: Mac, iPhone, PC, Android
# - В ислледовании 11 источников привлечения рекламы
#
# 4. Маркетинг
# - Посчитаны общие раходы на маркетинг - 105497
# - Больше всего траты идут на рекламные компании - TipTop и FaceBoom
# - Построили график с визвизуализацией динамики изменения расходов по неделям по месяцам. В основном траты идут на 2 рекламные компании - TipTop и FaceBoom
# - Дороже всего обходится привлечение пользователей через рекламную компанию - TipTop (почти 2.8)
#
# 5. Оценка окупаемости рекламы
# - Проанализировали окупаемость рекламы с помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI. Динамика ROI перестаёт окупаться почти в самом начале
# - Проверили конверсию и удержание пользователей и динамику их изменений по трём критериям:
#     - По устройствам: здесь в целом всё ровно за исключением, что конверсия пользователей PC меньше всего, но окупаемость в целом немного лучше других.
#     - По странам: конверсия пользователей из США примерно в 2 раза больше других стран, но удержание платящих пользователей хуже
#     - По рекламным каналам: Самая высокая конверсия у FaceBoom, но удержание платящих пользователей хуже всех (как у США по странам)
# - Проверили окупаемость рекламы:
#     - По устройствам: только реклама пользователей PC окупается.
#     - По странам: реклама по всем странам кроме США - окупается.
#     - По рекламным каналам: лучше всех показывает канал lambdaMediaAds и TipTop
# - Анализ возможных причин неокупаемости рекламы:
#     - Проблемы с окупаемостью рекламы связаны с неправильным распределением средств на эту рекламу
#     - Если убрать из привлечения такой источник как - TipTop, то реклама будет окупаться.
#     - Средства которые могли пойти на привлечения пользователей через TipTop, можно перераспределить на другие рекламные источники, такие как - lambdaMediaAds.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "FaceBoom" and channel != "TipTop"'), orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)
